# %% [markdown]
# <a href="https://colab.research.google.com/github/vidushi1920/Time-Series-Forecasting/blob/main/Time_Series_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/actual - dataset road.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#   Unnamed: 0  year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  \
# 0      Sec_1     1   324.0   354.5    17.0     0.0       3     117    2600
# 1        NaN     2   324.0   161.1    18.2     0.0       4     106    5950
# 2        NaN     3   324.0   170.7    18.5     0.0       4     110    5950
# 3        NaN     4   324.0   223.9    18.9     0.0       3     110    6150
# 4        NaN     5   324.0   228.2    18.4     0.0       2     113    6340
#
#    Para-8  Para-9  Para-10  Para-11  Para-12  Para-13
# 0     400     0.0      0.0      0.0        0     1.52
# 1    1190     0.0      3.4      0.0        0     1.62
# 2    1190     0.0     21.3      0.0        4     1.68
# 3    1340     0.0     21.3      0.0        5     1.78
# 4    1450     0.0     23.9      0.0        7     1.80

# %%
df.drop('Unnamed: 0',axis = 1,inplace=True)

# %%
df
# Out:
#       year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  Para-8  \
# 0        1   324.0   354.5    17.0     0.0       3     117    2600     400
# 1        2   324.0   161.1    18.2     0.0       4     106    5950    1190
# 2        3   324.0   170.7    18.5     0.0       4     110    5950    1190
# 3        4   324.0   223.9    18.9     0.0       3     110    6150    1340
# 4        5   324.0   228.2    18.4     0.0       2     113    6340    1450
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1004     6   454.0   931.8    13.6   125.0      13     116    4150     830
# 1005     7   454.0   703.0    14.5    17.0      13     118    4150     830
# 1006     8   454.0  1124.1    14.9    45.0      18     117    4200     840
# 1007     9   454.0  1462.3    13.2    62.0      27     117    4400     720
# 1008    10   454.0   986.3    14.3    67.0      24     122    4415     721
#
#       Para-9  Para-10  Para-11  Para-12  Para-13
# 0        0.0      0.0      0.0        0    1.520
# 1        0.0      3.4      0.0        0    1.620
# 2        0.0     21.3      0.0        4    1.680
# 3        0.0     21.3      0.0        5    1.780
# 4        0.0     23.9      0.0        7    1.800
# ...      ...      ...      ...      ...      ...
# 1004    15.1      1.8      1.0       15    1.681
# 1005    24.6      7.9      2.0       15    1.838
# 1006   119.0     15.7      2.0       16    1.862
# 1007   138.2     30.5      6.0       18    1.883
# 1008   293.0     39.8      7.0       18    1.889
#
# [1009 rows x 14 columns]

# %%
#Test Data
t_df = df[df['year'] == 10]
t_df
# Out:
#       year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  Para-8  \
# 9       10   324.0    53.6    19.0     0.0       2     105    7567    1885
# 19      10   327.7    62.0    22.7     0.0       2     102   30525   10234
# 29      10   487.7    93.2    22.5     0.0       4     110    2140    1270
# 39      10   543.6    93.2    22.5     0.0       4     110    2140    1270
# 49      10   434.4   149.0    11.7    72.0       3     110   13142    6225
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 968     10   514.0  1226.4    10.1   203.6      16     114    7672     303
# 978     10   901.0  1531.0    11.1    34.9      40     100   15150    1077
# 988     10  1181.0  1364.9     9.2   274.3      24     112   12500     880
# 998     10   662.0  1110.7    12.8    33.2      27     117    3324    1356
# 1008    10   454.0   986.3    14.3    67.0      24     122    4415     721
#
#       Para-9  Para-10  Para-11  Para-12  Para-13
# 9       16.8    105.0     65.0        9    1.960
# 19      76.5     44.3      5.0        9    0.795
# 29      78.5      0.0      0.0       16    1.432
# 39      28.5     60.5     67.0       11    2.004
# 49       0.0    276.2     34.0        6    1.792
# ...      ...      ...      ...      ...      ...
# 968    219.7    206.2     10.0        8    1.607
# 978      5.9     74.5     33.0       13    1.087
# 988    131.4     72.4     18.0       12    0.996
# 998    193.7    305.6    180.0       12    2.212
# 1008   293.0     39.8      7.0       18    1.889
#
# [100 rows x 14 columns]

# %%
t_df = t_df.reset_index()
t_df.head()
# Out:
#    index  year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  \
# 0      9    10   324.0    53.6    19.0     0.0       2     105    7567
# 1     19    10   327.7    62.0    22.7     0.0       2     102   30525
# 2     29    10   487.7    93.2    22.5     0.0       4     110    2140
# 3     39    10   543.6    93.2    22.5     0.0       4     110    2140
# 4     49    10   434.4   149.0    11.7    72.0       3     110   13142
#
#    Para-8  Para-9  Para-10  Para-11  Para-12  Para-13
# 0    1885    16.8    105.0     65.0        9    1.960
# 1   10234    76.5     44.3      5.0        9    0.795
# 2    1270    78.5      0.0      0.0       16    1.432
# 3    1270    28.5     60.5     67.0       11    2.004
# 4    6225     0.0    276.2     34.0        6    1.792

# %%
t_df.drop('index',axis = 1,inplace = True)

# %%
t_df
# Out:
#     year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  Para-8  \
# 0     10   324.0    53.6    19.0     0.0       2     105    7567    1885
# 1     10   327.7    62.0    22.7     0.0       2     102   30525   10234
# 2     10   487.7    93.2    22.5     0.0       4     110    2140    1270
# 3     10   543.6    93.2    22.5     0.0       4     110    2140    1270
# 4     10   434.4   149.0    11.7    72.0       3     110   13142    6225
# ..   ...     ...     ...     ...     ...     ...     ...     ...     ...
# 95    10   514.0  1226.4    10.1   203.6      16     114    7672     303
# 96    10   901.0  1531.0    11.1    34.9      40     100   15150    1077
# 97    10  1181.0  1364.9     9.2   274.3      24     112   12500     880
# 98    10   662.0  1110.7    12.8    33.2      27     117    3324    1356
# 99    10   454.0   986.3    14.3    67.0      24     122    4415     721
#
#     Para-9  Para-10  Para-11  Para-12  Para-13
# 0     16.8    105.0     65.0        9    1.960
# 1     76.5     44.3      5.0        9    0.795
# 2     78.5      0.0      0.0       16    1.432
# 3     28.5     60.5     67.0       11    2.004
# 4      0.0    276.2     34.0        6    1.792
# ..     ...      ...      ...      ...      ...
# 95   219.7    206.2     10.0        8    1.607
# 96     5.9     74.5     33.0       13    1.087
# 97   131.4     72.4     18.0       12    0.996
# 98   193.7    305.6    180.0       12    2.212
# 99   293.0     39.8      7.0       18    1.889
#
# [100 rows x 14 columns]

# %%
# removing section 92 as target row is not present
df.drop([910,911,912,913,914,915,916,917,918],axis = 0,inplace = True)
df
# Out:
#       year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  Para-8  \
# 0        1   324.0   354.5    17.0     0.0       3     117    2600     400
# 1        2   324.0   161.1    18.2     0.0       4     106    5950    1190
# 2        3   324.0   170.7    18.5     0.0       4     110    5950    1190
# 3        4   324.0   223.9    18.9     0.0       3     110    6150    1340
# 4        5   324.0   228.2    18.4     0.0       2     113    6340    1450
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1004     6   454.0   931.8    13.6   125.0      13     116    4150     830
# 1005     7   454.0   703.0    14.5    17.0      13     118    4150     830
# 1006     8   454.0  1124.1    14.9    45.0      18     117    4200     840
# 1007     9   454.0  1462.3    13.2    62.0      27     117    4400     720
# 1008    10   454.0   986.3    14.3    67.0      24     122    4415     721
#
#       Para-9  Para-10  Para-11  Para-12  Para-13
# 0        0.0      0.0      0.0        0    1.520
# 1        0.0      3.4      0.0        0    1.620
# 2        0.0     21.3      0.0        4    1.680
# 3        0.0     21.3      0.0        5    1.780
# 4        0.0     23.9      0.0        7    1.800
# ...      ...      ...      ...      ...      ...
# 1004    15.1      1.8      1.0       15    1.681
# 1005    24.6      7.9      2.0       15    1.838
# 1006   119.0     15.7      2.0       16    1.862
# 1007   138.2     30.5      6.0       18    1.883
# 1008   293.0     39.8      7.0       18    1.889
#
# [1000 rows x 14 columns]

# %%
df = df.reset_index()
df.drop('index',axis = 1,inplace = True)
df
# Out:
#      year  Para-1  Para-2  Para-3  Para-4  Para-5  Para-6  Para-7  Para-8  \
# 0       1   324.0   354.5    17.0     0.0       3     117    2600     400
# 1       2   324.0   161.1    18.2     0.0       4     106    5950    1190
# 2       3   324.0   170.7    18.5     0.0       4     110    5950    1190
# 3       4   324.0   223.9    18.9     0.0       3     110    6150    1340
# 4       5   324.0   228.2    18.4     0.0       2     113    6340    1450
# ..    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 995     6   454.0   931.8    13.6   125.0      13     116    4150     830
# 996     7   454.0   703.0    14.5    17.0      13     118    4150     830
# 997     8   454.0  1124.1    14.9    45.0      18     117    4200     840
# 998     9   454.0  1462.3    13.2    62.0      27     117    4400     720
# 999    10   454.0   986.3    14.3    67.0      24     122    4415     721
#
#      Para-9  Para-10  Para-11  Para-12  Para-13
# 0       0.0      0.0      0.0        0    1.520
# 1       0.0      3.4      0.0        0    1.620
# 2       0.0     21.3      0.0        4    1.680
# 3       0.0     21.3      0.0        5    1.780
# 4       0.0     23.9      0.0        7    1.800
# ..      ...      ...      ...      ...      ...
# 995    15.1      1.8      1.0       15    1.681
# 996    24.6      7.9      2.0       15    1.838
# 997   119.0     15.7      2.0       16    1.862
# 998   138.2     30.5      6.0       18    1.883
# 999   293.0     39.8      7.0       18    1.889
#
# [1000 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['year', 'Para-1', 'Para-2', 'Para-3', 'Para-4', 'Para-5', 'Para-6',
#        'Para-7', 'Para-8', 'Para-9', 'Para-10', 'Para-11', 'Para-12',
#        'Para-13'],
#       dtype='object')

# %%
# Seperate data frames for each section
sec = 1
for i in range(0,len(df),10):
  new_df = pd.DataFrame(columns=['year', 'Para-1', 'Para-2', 'Para-3', 'Para-4', 'Para-5', 'Para-6',
       'Para-7', 'Para-8', 'Para-9', 'Para-10', 'Para-11', 'Para-12',
       'Para-13'])
  for j in range(0,10):
    row = df.loc[i+j,:]
    new_df = new_df.append(row)
  new_df.to_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(sec)+".csv", index=False)
  sec = sec + 1
  if(sec == 92):
    sec = sec + 1

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose
from math import sqrt

# %%
import xgboost as xgb

# %%
def train_time_series_with_folds(temp_df, section, horizon=1):
  x = temp_df.drop(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'], axis=1)
  y = temp_df['Para-9']

  # Take 10th year of dataset for validation
  x_train, x_test = x.iloc[:-horizon, :], x.iloc[-horizon:, :]
  y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

  model = LGBMRegressor(random_state=42)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  rmse = np.round(sqrt(mean_squared_error(y_test, predictions)), 3)

  actual = y_test.values
  rmse_df = pd.DataFrame(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'])
  rmse_df.loc[0, 'Para-9'] = actual[0]
  rmse_df.loc[1, 'Para-9'] = np.round(predictions[0], 3)
  rmse_df.loc[2, 'Para-9'] = rmse
  rmse_df.to_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(sec)+".csv", index=False)

# %%
def train_time_series_with_folds_2(temp_df, section, horizon=1):
  x = temp_df.drop(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'], axis=1)
  y = temp_df['Para-10']

  # Take 10th year of dataset for validation
  x_train, x_test = x.iloc[:-horizon, :], x.iloc[-horizon:, :]
  y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

  model = LGBMRegressor(random_state=42)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  rmse = np.round(sqrt(mean_squared_error(y_test, predictions)), 3)

  actual = y_test.values
  rmse_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(sec)+".csv")
  rmse_df.loc[0, 'Para-10'] = actual[0]
  rmse_df.loc[1, 'Para-10'] = np.round(predictions[0], 3)
  rmse_df.loc[2, 'Para-10'] = rmse
  rmse_df.to_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv", index=False)

# %%
def train_time_series_with_folds_3(temp_df, section, horizon=1):
  x = temp_df.drop(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'], axis=1)
  y = temp_df['Para-11']

  # Take 10th year of dataset for validation
  x_train, x_test = x.iloc[:-horizon, :], x.iloc[-horizon:, :]
  y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

  model = LGBMRegressor(random_state=42)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  rmse = np.round(sqrt(mean_squared_error(y_test, predictions)), 3)

  actual = y_test.values
  rmse_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv")
  rmse_df.loc[0, 'Para-11'] = actual[0]
  rmse_df.loc[1, 'Para-11'] = np.round(predictions[0], 3)
  rmse_df.loc[2, 'Para-11'] = rmse
  rmse_df.to_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv", index=False)

# %%
def train_time_series_with_folds_4(temp_df, section, horizon=1):
  x = temp_df.drop(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'], axis=1)
  y = temp_df['Para-12']

  # Take 10th year of dataset for validation
  x_train, x_test = x.iloc[:-horizon, :], x.iloc[-horizon:, :]
  y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

  model = LGBMRegressor(random_state=42)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  rmse = np.round(sqrt(mean_squared_error(y_test, predictions)), 3)

  actual = y_test.values
  rmse_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv")
  rmse_df.loc[0, 'Para-12'] = actual[0]
  rmse_df.loc[1, 'Para-12'] = np.round(predictions[0], 3)
  rmse_df.loc[2, 'Para-12'] = rmse
  rmse_df.to_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv", index=False)

# %%
def train_time_series_with_folds_5(temp_df, section, horizon=1):
  x = temp_df.drop(columns=['Para-9', 'Para-10',	'Para-11',	'Para-12',	'Para-13'], axis=1)
  y = temp_df['Para-13']

  # Take 10th year of dataset for validation
  x_train, x_test = x.iloc[:-horizon, :], x.iloc[-horizon:, :]
  y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

  model = LGBMRegressor(random_state=42)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  rmse = np.round(sqrt(mean_squared_error(y_test, predictions)), 3)

  actual = y_test.values
  rmse_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv")
  rmse_df.loc[0, 'Para-13'] = actual[0]
  rmse_df.loc[1, 'Para-13'] = np.round(predictions[0], 3)
  rmse_df.loc[2, 'Para-13'] = rmse
  rmse_df.to_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(section)+".csv", index=False)

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  sec_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(i)+".csv")
  train_time_series_with_folds(sec_df, i)

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  sec_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(i)+".csv")
  train_time_series_with_folds_2(sec_df, i)

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  sec_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(i)+".csv")
  train_time_series_with_folds_3(sec_df, i)

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  sec_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(i)+".csv")
  train_time_series_with_folds_4(sec_df, i)

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  sec_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/sections/sec"+str(i)+".csv")
  train_time_series_with_folds_5(sec_df, i)

# %%
list1 = []

def comparison_graph(rmse_df, section):
  mean_rmse = np.round(rmse_df.iloc[2, :].mean(axis=0), 3)
  list1.append(mean_rmse)
  line_1 = rmse_df.iloc[0, :]
  line_2 = rmse_df.iloc[1, :]
  fig, ax = plt.subplots()
  ax.plot(line_1, color = 'green', label = 'Actual')
  ax.plot(line_2, color = 'red', label = 'Predicted')
  plt.title("RMSE: "+str(mean_rmse))
  ax.legend()
  plt.savefig("/content/drive/MyDrive/Time_Series_Project/graphs/sec"+str(section)+".png")
  plt.close()

# %%
for i in range(1, 102):
  if (i == 92):
    continue
  rmse_df = pd.read_csv("/content/drive/MyDrive/Time_Series_Project/rmse_comparisons/sec"+str(i)+".csv")
  comparison_graph(rmse_df, i)

# %%
f_rmse = sum(list1)/len(list1)
print("RMSE: ", np.round(f_rmse, 3))
# Out:
# RMSE:  74.28
